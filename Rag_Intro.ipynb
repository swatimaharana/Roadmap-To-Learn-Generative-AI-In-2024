# %% [markdown]
# <a href="https://colab.research.google.com/github/swatimaharana/Roadmap-To-Learn-Generative-AI-In-2024/blob/main/Rag_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe = pipeline("text-generation", model="Qwen/Qwen2.5-1.5B-Instruct")
pipe(messages)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# ...

# %%
question1 = "what is an ACE in Tennis?"
question2 = "what is a Volley ?"

prompt = "Answer the question\n" + \
"Question: "+ question1 + "\n" + "Answer:"
print(prompt)
# Out:
# Answer the question
# Question: what is an ACE in Tennis?
# Answer:

# %%
result = pipe(prompt,max_new_tokens = 50)
print(result)
# Out:
# [{'generated_text': "Answer the question\nQuestion: what is an ACE in Tennis?\nAnswer: An Ace in tennis refers to a successful serve that lands on the opponent's side of the net without touching the ground or being hit by their racket. It is considered one of the most difficult shots in the game and can be achieved with practice, strength"}]

# %%
question1 = "what is an ACE in Tennis?"
question2 = "what is a Volley ?"

prompt = "Answer the question\n" + \
"Question: "+ question2 + "\n" + "Answer:"
print(prompt)
# Out:
# Answer the question
# Question: what is a Volley ?
# Answer:

# %%
result = pipe(prompt,max_new_tokens = 50)
print(result)
# Out:
# [{'generated_text': 'Answer the question\nQuestion: what is a Volley ?\nAnswer: A volley in volleyball refers to when a player hits the ball back into play after it has been returned by an opponent. This is done to maintain possession of the ball and prevent the opposing team from scoring points. The purpose of a volley is to gain'}]

# %%
context = """ACE is a serve that lands in the correct
service court without the receiving player touching
it with their racket, resulting in a point for the server.
When a player hits an ace, they immediately win the point,
regardless of the opponent's position or attempted return.
The term ace in tennis was coined by sports journalist Allison Danzig. """

prompt = "Answer the question using the below context.\n" + \
"Context: " + context + "\n" + \
"Question: "+ question1 + "\n" + "Answer:"
print(prompt)
# Out:
# Answer the question using the below context.
# Context: ACE is a serve that lands in the correct
# service court without the receiving player touching
# it with their racket, resulting in a point for the server.
# When a player hits an ace, they immediately win the point,
# regardless of the opponent's position or attempted return.
# The term ace in tennis was coined by sports journalist Allison Danzig.
# Question: what is an ACE in Tennis?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# [{'generated_text': "Answer the question using the below context.\nContext: ACE is a serve that lands in the correct\nservice court without the receiving player touching\nit with their racket, resulting in a point for the server.\nWhen a player hits an ace, they immediately win the point,\nregardless of the opponent's position or attempted return.\nThe term ace in tennis was coined by sports journalist Allison Danzig. \nQuestion: what is an ACE in Tennis?\nAnswer: An ace in tennis is when a player successfully serves the ball into the correct service court without it being touched by the receiving player's racket, leading to a point for the server and immediate victory on that occasion.\n\nAce in Tennis is defined as a serve"}]

# %%
context = """In tennis, a volley is a shot where the
ball is struck before it bounces on the ground,
typically performed near the net,
aiming to end the point quickly or
disrupt the opponent's rhythm."""

prompt = "Answer the question using the below context.\n" + \
"Context: " + context + "\n" + \
"Question: "+ question2 + "\n" + "Answer:"
print(prompt)
# Out:
# Answer the question using the below context.
# Context: In tennis, a volley is a shot where the
# ball is struck before it bounces on the ground,
# typically performed near the net,
# aiming to end the point quickly or
# disrupt the opponent's rhythm.
# Question: what is a Volley ?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
